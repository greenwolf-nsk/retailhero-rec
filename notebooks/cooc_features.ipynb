# %%
import json

# %%
with open('../cooc_dict.json', 'r') as f:
    res = json.load(f)

# %%
res['9a80204f78']
# Out:
# {'da89ebd374': 7,
#  '0a95e1151d': 4,
#  '4055b15e4a': 14,
#  'a685f1916b': 1,
#  '21db5dbe53': 4,
#  '1e208d0b4c': 4,
#  '15ccaa8685': 321,
#  '45389bb5b0': 3,
#  'cb4c804130': 10,
#  '7c39f1d12c': 16,
#  '63e2eac70d': 1,
#  'c7cc613e79': 4,
#  'ad865591c6': 55,
#  '7118c66f7f': 2,
#  'c55ed13ebd': 5,
#  '9cdad65286': 2,
#  '17cf3963fb': 18,
#  '6bbace0869': 1,
#  '7b79a3060e': 6,
#  'c4f905c99e': 4,
#  'b24ab2d077': 8,
#  '7cb8fa065e': 21,
#  'ee17733c1a': 43,
#  'cbe1cd3bb3': 130,
#  '2dff69ae83': 5,
#  '3f5806f1b7': 1,
#  '19bcc78352': 8,
#  '9de555b529': 13,
#  'c98792115f': 1,
#  '0296ae3c3b': 15,
#  '439498bce2': 207,
#  'fb0b7dae94': 1,
#  '0de4e61711': 692,
#  '5ad359f9d7': 138,
#  '6c452af8f6': 5,
#  '4ec64ff3ff': 2,
#  '3926be9a96': 4,
#  '639cffebd3': 4,
#  '11117845fa': 5,
#  '2c4574641a': 2,
#  '8fd587ee86': 3,
#  'f5b37ae38d': 3,
#  '4009f09b04': 1223,
#  '6d28052328': 1,
#  'c3e93cf9c8': 1,
#  'e75c1c5e1c': 2,
#  '3a7eff7bbe': 10,
#  '4dcf79043e': 140,
# ...
